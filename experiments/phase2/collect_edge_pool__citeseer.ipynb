# %%
from greedy_mcmc_attack import *
from collections import defaultdict

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# dataset_directory = "../Cora"
cora_dataset = Planetoid(root='', name='Citeseer')
data = cora_dataset[0].to(device)
print(data)
# Out:
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])

# %%
model = GCN(data.x.shape[1], cora_dataset.num_classes, [16]).to(device)

# %%
model_save_path = "../models/citeseer_gcn_model.pth"
list_save_path = "../attacks/citeseer_gcn_edges.pth"
# # multi_metattack_edges_list.pth
# list_save_path = "multi_metattack_edges_list.pth"

# %%
model, edges_to_add, train = load_model_and_edges(model_save_path, list_save_path, model, device)

# %%
# Get initial accuracy
initial_loss, initial_accuracy = train.test(data)
print(f"Initial Accuracy: {initial_accuracy}")
print(f"Initial Loss: {initial_loss}")
# Out:
# Initial Accuracy: 0.69
# Initial Loss: 1.2167096138000488

# %%
amts = defaultdict(int)

for _ in range(1):
    attacker = Metattack(data, device=device)
    attacker.setup_surrogate(
        model,
        labeled_nodes=data.train_mask,
        unlabeled_nodes=data.test_mask,
        lambda_=0.0,
    )
    attacker.reset()
    attacker.attack(2)

    for edge, itr in attacker._added_edges.items():
        amts[edge] = itr

    for edge, itr in attacker._removed_edges.items():
        amts[edge] = itr

sorted_list = sorted(amts.items(), key=lambda item: item[1], reverse=False)
sorted_keys = [key for key, value in sorted_list]

sorted_keys
# Out:
# Peturbing graph...:   0%|          | 0/9104 [00:00<?, ?it/s]
# Surrogate loss on unlabled data: 1.0191107988357544
# Surrogate acc on unlabled data: 0.704
# Attack loss: 0.3346502482891083
# Surrogate loss on unlabled data: 1.2053171396255493
# Surrogate acc on unlabled data: 0.643
# Attack loss: 0.5813760161399841
# Surrogate loss on unlabled data: 1.3040577173233032
# Surrogate acc on unlabled data: 0.621
# Attack loss: 0.7268013954162598
# Surrogate loss on unlabled data: 1.3943349123001099
# Surrogate acc on unlabled data: 0.618
# Attack loss: 0.9455540776252747
# Surrogate loss on unlabled data: 1.5203423500061035
# Surrogate acc on unlabled data: 0.612
# Attack loss: 1.031607985496521
# Surrogate loss on unlabled data: 1.6286119222640991
# Surrogate acc on unlabled data: 0.56
# Attack loss: 1.1620756387710571
# Surrogate loss on unlabled data: 1.6699966192245483
# Surrogate acc on unlabled data: 0.541
# Attack loss: 1.295115351676941
# Surrogate loss on unlabled data: 1.8568389415740967
# Surrogate acc on unlabled data: 0.523
# Attack loss: 1.414124608039856
# Surrogate loss on unlabled data: 1.910125970840454
# Surrogate acc on unlabled data: 0.517
# Attack loss: 1.5061863660812378
# Surrogate loss on unlabled data: 2.0915303230285645
# Surrogate acc on unlabled data: 0.504
# Attack loss: 1.679978609085083
# Surrogate loss on unlabled data: 2.0212464332580566
# Surrogate acc on unlabled data: 0.493
# Attack loss: 1.6694817543029785
# Surrogate loss on unlabled data: 2.216935396194458
# Surrogate acc on unlabled data: 0.47300000000000003
# Attack loss: 1.884088158607483
# Surrogate loss on unlabled data: 2.243330478668213
# Surrogate acc on unlabled data: 0.466
# Attack loss: 1.9338481426239014
# Surrogate loss on unlabled data: 2.3657658100128174
# Surrogate acc on unlabled data: 0.458
# Attack loss: 2.0672051906585693
# Surrogate loss on unlabled data: 2.5835163593292236
# Surrogate acc on unlabled data: 0.445
# Attack loss: 2.277177095413208
# Surrogate loss on unlabled data: 2.696981906890869
# Surrogate acc on unlabled data: 0.442
# Attack loss: 2.3863627910614014
# Surrogate loss on unlabled data: 2.69995379447937
# Surrogate acc on unlabled data: 0.452
# Attack loss: 2.3890414237976074
# Surrogate loss on unlabled data: 2.8235957622528076
# Surrogate acc on unlabled data: 0.438
# Attack loss: 2.586541175842285
# Surrogate loss on unlabled data: 2.6575446128845215
# Surrogate acc on unlabled data: 0.426
# Attack loss: 2.435620069503784
# Surrogate loss on unlabled data: 3.137554407119751
# Surrogate acc on unlabled data: 0.396
# Attack loss: 2.8959262371063232
# Surrogate loss on unlabled data: 3.1412246227264404
# Surrogate acc on unlabled data: 0.387
# Attack loss: 2.9385437965393066
# Surrogate loss on unlabled data: 3.281118154525757
# Surrogate acc on unlabled data: 0.354
# Attack loss: 3.0866708755493164
# Surrogate loss on unlabled data: 3.315624237060547
# Surrogate acc on unlabled data: 0.339
# Attack loss: 3.190985679626465
# Surrogate loss on unlabled data: 3.4667701721191406
# Surrogate acc on unlabled data: 0.326
# Attack loss: 3.3014702796936035
# Surrogate loss on unlabled data: 3.37722110748291
# Surrogate acc on unlabled data: 0.319
# Attack loss: 3.2788100242614746
# Surrogate loss on unlabled data: 3.5192275047302246
# Surrogate acc on unlabled data: 0.306
# Attack loss: 3.390872001647949
# Surrogate loss on unlabled data: 3.8279519081115723
# Surrogate acc on unlabled data: 0.304
# Attack loss: 3.6964752674102783
# Surrogate loss on unlabled data: 3.56921648979187
# Surrogate acc on unlabled data: 0.28300000000000003
# Attack loss: 3.448948621749878
# Surrogate loss on unlabled data: 3.9209234714508057
# Surrogate acc on unlabled data: 0.28800000000000003
# Attack loss: 3.8162550926208496
# Surrogate loss on unlabled data: 4.010530471801758
# Surrogate acc on unlabled data: 0.278
# Attack loss: 3.893740653991699
# Surrogate loss on unlabled data: 4.090137958526611
# Surrogate acc on unlabled data: 0.274
# Attack loss: 3.996373176574707
# Surrogate loss on unlabled data: 4.297675609588623
# Surrogate acc on unlabled data: 0.254
# Attack loss: 4.128000259399414
# Surrogate loss on unlabled data: 4.506567478179932
# Surrogate acc on unlabled data: 0.255
# Attack loss: 4.374054431915283
# Surrogate loss on unlabled data: 4.719942569732666
# Surrogate acc on unlabled data: 0.246
# Attack loss: 4.5878143310546875
# Surrogate loss on unlabled data: 4.925083637237549
# Surrogate acc on unlabled data: 0.23
# Attack loss: 4.78236722946167
# Surrogate loss on unlabled data: 5.151467800140381
# Surrogate acc on unlabled data: 0.23800000000000002
# Attack loss: 4.982751369476318
# Surrogate loss on unlabled data: 5.190207481384277
# Surrogate acc on unlabled data: 0.216
# Attack loss: 5.03780460357666
# Surrogate loss on unlabled data: 4.973456859588623
# Surrogate acc on unlabled data: 0.20400000000000001
# Attack loss: 4.882399559020996
# Surrogate loss on unlabled data: 5.6193413734436035
# Surrogate acc on unlabled data: 0.20600000000000002
# Attack loss: 5.474496364593506
# Surrogate loss on unlabled data: 5.59957218170166
# Surrogate acc on unlabled data: 0.176
# Attack loss: 5.494681358337402
# Surrogate loss on unlabled data: 5.583438396453857
# Surrogate acc on unlabled data: 0.181
# Attack loss: 5.466250419616699
# Surrogate loss on unlabled data: 5.539908409118652
# Surrogate acc on unlabled data: 0.171
# Attack loss: 5.431069374084473
# Surrogate loss on unlabled data: 5.892514705657959
# Surrogate acc on unlabled data: 0.162
# Attack loss: 5.779733180999756
# Surrogate loss on unlabled data: 5.6975932121276855
# Surrogate acc on unlabled data: 0.147
# Attack loss: 5.628036022186279
# Surrogate loss on unlabled data: 5.950575351715088
# Surrogate acc on unlabled data: 0.152
# Attack loss: 5.863720417022705
# Surrogate loss on unlabled data: 6.136280059814453
# Surrogate acc on unlabled data: 0.148
# Attack loss: 6.01821231842041
# Surrogate loss on unlabled data: 5.890979766845703
# Surrogate acc on unlabled data: 0.147
# Attack loss: 5.774630069732666
# Surrogate loss on unlabled data: 5.927022457122803
# Surrogate acc on unlabled data: 0.135
# Attack loss: 5.819174766540527
# Surrogate loss on unlabled data: 6.232907772064209
# Surrogate acc on unlabled data: 0.14100000000000001
# Attack loss: 6.14455509185791
# Surrogate loss on unlabled data: 6.093212604522705
# Surrogate acc on unlabled data: 0.14400000000000002
# Attack loss: 6.033503532409668
# Surrogate loss on unlabled data: 6.575888633728027
# Surrogate acc on unlabled data: 0.14200000000000002
# Attack loss: 6.48680305480957
# Surrogate loss on unlabled data: 6.582002639770508
# Surrogate acc on unlabled data: 0.136
# Attack loss: 6.532137393951416
# Surrogate loss on unlabled data: 6.713347911834717
# Surrogate acc on unlabled data: 0.145
# Attack loss: 6.638105392456055
# Surrogate loss on unlabled data: 6.7084150314331055
# Surrogate acc on unlabled data: 0.13
# Attack loss: 6.636804580688477
# Surrogate loss on unlabled data: 6.799628734588623
# Surrogate acc on unlabled data: 0.135
# Attack loss: 6.757872104644775
# Surrogate loss on unlabled data: 6.656368732452393
# Surrogate acc on unlabled data: 0.139
# Attack loss: 6.566183090209961
# Surrogate loss on unlabled data: 6.955533981323242
# Surrogate acc on unlabled data: 0.132
# Attack loss: 6.884737491607666
# Surrogate loss on unlabled data: 7.045648097991943
# Surrogate acc on unlabled data: 0.134
# Attack loss: 6.968297481536865
# Surrogate loss on unlabled data: 7.315886974334717
# Surrogate acc on unlabled data: 0.122
# Attack loss: 7.244419097900391
# Surrogate loss on unlabled data: 7.3404645919799805
# Surrogate acc on unlabled data: 0.126
# Attack loss: 7.2427978515625
# Surrogate loss on unlabled data: 7.84627628326416
# Surrogate acc on unlabled data: 0.13
# Attack loss: 7.746494293212891
# Surrogate loss on unlabled data: 7.635908603668213
# Surrogate acc on unlabled data: 0.116
# Attack loss: 7.564900875091553
# Surrogate loss on unlabled data: 7.847360610961914
# Surrogate acc on unlabled data: 0.112
# Attack loss: 7.785804271697998
# Surrogate loss on unlabled data: 7.588176250457764
# Surrogate acc on unlabled data: 0.112
# Attack loss: 7.496072769165039
# Surrogate loss on unlabled data: 8.096357345581055
# Surrogate acc on unlabled data: 0.116
# Attack loss: 8.02988338470459
# Surrogate loss on unlabled data: 8.012175559997559
# Surrogate acc on unlabled data: 0.11
# Attack loss: 7.92211389541626
# Surrogate loss on unlabled data: 8.1458158493042
# Surrogate acc on unlabled data: 0.107
# Attack loss: 8.083897590637207
# Surrogate loss on unlabled data: 8.178472518920898
# Surrogate acc on unlabled data: 0.108
# Attack loss: 8.106616973876953
# Surrogate loss on unlabled data: 7.78176736831665
# Surrogate acc on unlabled data: 0.106
# Attack loss: 7.722751617431641
# Surrogate loss on unlabled data: 8.049251556396484
# Surrogate acc on unlabled data: 0.101
# Attack loss: 8.015369415283203
# Surrogate loss on unlabled data: 8.232640266418457
# Surrogate acc on unlabled data: 0.1
# Attack loss: 8.19191837310791
# Surrogate loss on unlabled data: 8.069076538085938
# Surrogate acc on unlabled data: 0.094
# Attack loss: 8.015705108642578
# Surrogate loss on unlabled data: 8.254434585571289
# Surrogate acc on unlabled data: 0.094
# Attack loss: 8.180810928344727
# Surrogate loss on unlabled data: 8.469803810119629
# Surrogate acc on unlabled data: 0.091
# Attack loss: 8.450238227844238
# Surrogate loss on unlabled data: 8.34337329864502
# Surrogate acc on unlabled data: 0.094
# Attack loss: 8.310638427734375
# Surrogate loss on unlabled data: 8.351676940917969
# Surrogate acc on unlabled data: 0.092
# Attack loss: 8.316071510314941
# Surrogate loss on unlabled data: 8.579362869262695
# Surrogate acc on unlabled data: 0.09
# Attack loss: 8.514548301696777
# Surrogate loss on unlabled data: 9.077629089355469
# Surrogate acc on unlabled data: 0.092
# Attack loss: 9.044013023376465
# Surrogate loss on unlabled data: 7.94249963760376
# Surrogate acc on unlabled data: 0.089
# Attack loss: 7.91514253616333
# Surrogate loss on unlabled data: 8.459582328796387
# Surrogate acc on unlabled data: 0.08700000000000001
# Attack loss: 8.417343139648438
# Surrogate loss on unlabled data: 8.026448249816895
# Surrogate acc on unlabled data: 0.083
# Attack loss: 8.013460159301758
# Surrogate loss on unlabled data: 8.79910659790039
# Surrogate acc on unlabled data: 0.081
# Attack loss: 8.740763664245605
# Surrogate loss on unlabled data: 8.909692764282227
# Surrogate acc on unlabled data: 0.085
# Attack loss: 8.877388954162598
# Surrogate loss on unlabled data: 8.380861282348633
# Surrogate acc on unlabled data: 0.081
# Attack loss: 8.37736988067627
# Surrogate loss on unlabled data: 8.483112335205078
# Surrogate acc on unlabled data: 0.084
# Attack loss: 8.511284828186035
# Surrogate loss on unlabled data: 8.99216365814209
# Surrogate acc on unlabled data: 0.082
# Attack loss: 8.959095001220703
# Surrogate loss on unlabled data: 8.219890594482422
# Surrogate acc on unlabled data: 0.085
# Attack loss: 8.26264762878418
# Surrogate loss on unlabled data: 9.581233024597168
# Surrogate acc on unlabled data: 0.081
# Attack loss: 9.539057731628418
# Surrogate loss on unlabled data: 9.141183853149414
# Surrogate acc on unlabled data: 0.08
# Attack loss: 9.152470588684082
# Surrogate loss on unlabled data: 9.057225227355957
# Surrogate acc on unlabled data: 0.075
# Attack loss: 9.018343925476074
# Surrogate loss on unlabled data: 9.178061485290527
# Surrogate acc on unlabled data: 0.076
# Attack loss: 9.17167854309082
# Surrogate loss on unlabled data: 8.882756233215332
# Surrogate acc on unlabled data: 0.074
# Attack loss: 8.892539024353027
# Surrogate loss on unlabled data: 9.598379135131836
# Surrogate acc on unlabled data: 0.081
# Attack loss: 9.601840019226074
# Surrogate loss on unlabled data: 9.558082580566406
# Surrogate acc on unlabled data: 0.07100000000000001
# Attack loss: 9.548611640930176
# Surrogate loss on unlabled data: 9.459413528442383
# Surrogate acc on unlabled data: 0.079
# Attack loss: 9.457913398742676
# Surrogate loss on unlabled data: 9.715539932250977
# Surrogate acc on unlabled data: 0.076
# Attack loss: 9.704038619995117
# Surrogate loss on unlabled data: 9.741144180297852
# Surrogate acc on unlabled data: 0.075
# Attack loss: 9.75122356414795
# Surrogate loss on unlabled data: 9.069284439086914
# Surrogate acc on unlabled data: 0.075
# Attack loss: 9.090149879455566
# Surrogate loss on unlabled data: 8.953675270080566
# Surrogate acc on unlabled data: 0.075
# Attack loss: 9.005547523498535
# Surrogate loss on unlabled data: 9.265959739685059
# Surrogate acc on unlabled data: 0.078
# Attack loss: 9.302689552307129
# Surrogate loss on unlabled data: 9.69277286529541
# Surrogate acc on unlabled data: 0.077
# Attack loss: 9.687905311584473
# Surrogate loss on unlabled data: 9.424941062927246
# Surrogate acc on unlabled data: 0.081
# Attack loss: 9.427875518798828
# Surrogate loss on unlabled data: 9.27685260772705
# Surrogate acc on unlabled data: 0.078
# Attack loss: 9.278043746948242
# Surrogate loss on unlabled data: 9.989262580871582
# Surrogate acc on unlabled data: 0.075
# Attack loss: 9.980385780334473
# Surrogate loss on unlabled data: 9.601709365844727
# Surrogate acc on unlabled data: 0.079
# Attack loss: 9.624695777893066
# Surrogate loss on unlabled data: 10.016763687133789
# Surrogate acc on unlabled data: 0.074
# Attack loss: 10.071542739868164
# Surrogate loss on unlabled data: 9.880327224731445
# Surrogate acc on unlabled data: 0.077
# Attack loss: 9.941256523132324
# Surrogate loss on unlabled data: 9.678828239440918
# Surrogate acc on unlabled data: 0.075
# Attack loss: 9.723224639892578
# Surrogate loss on unlabled data: 9.732551574707031
# Surrogate acc on unlabled data: 0.074
# Attack loss: 9.75951862335205
# Surrogate loss on unlabled data: 10.526449203491211
# Surrogate acc on unlabled data: 0.073
# Attack loss: 10.610916137695312
# Surrogate loss on unlabled data: 9.881593704223633
# Surrogate acc on unlabled data: 0.076
# Attack loss: 9.959304809570312
# Surrogate loss on unlabled data: 10.350980758666992
# Surrogate acc on unlabled data: 0.07200000000000001
# Attack loss: 10.40573501586914
# Surrogate loss on unlabled data: 10.380637168884277
# Surrogate acc on unlabled data: 0.07200000000000001
# Attack loss: 10.458908081054688
# Surrogate loss on unlabled data: 10.29117488861084
# Surrogate acc on unlabled data: 0.074
# Attack loss: 10.347975730895996
# Surrogate loss on unlabled data: 10.396153450012207
# Surrogate acc on unlabled data: 0.076
# Attack loss: 10.454734802246094
# Surrogate loss on unlabled data: 10.5029296875
# Surrogate acc on unlabled data: 0.07100000000000001
# Attack loss: 10.572482109069824
# Surrogate loss on unlabled data: 10.854397773742676
# Surrogate acc on unlabled data: 0.073
# Attack loss: 10.952476501464844
# Surrogate loss on unlabled data: 10.499269485473633
# Surrogate acc on unlabled data: 0.074
# Attack loss: 10.550729751586914
# Surrogate loss on unlabled data: 10.303258895874023
# Surrogate acc on unlabled data: 0.07100000000000001
# Attack loss: 10.417320251464844
# Surrogate loss on unlabled data: 10.454063415527344
# Surrogate acc on unlabled data: 0.07
# Attack loss: 10.554511070251465
# Surrogate loss on unlabled data: 10.23108959197998
# Surrogate acc on unlabled data: 0.07100000000000001
# Attack loss: 10.349259376525879
# Surrogate loss on unlabled data: 10.196269989013672
# Surrogate acc on unlabled data: 0.074
# Attack loss: 10.29439640045166
# Surrogate loss on unlabled data: 9.890439987182617
# Surrogate acc on unlabled data: 0.07200000000000001
# Attack loss: 9.935953140258789
# Surrogate loss on unlabled data: 10.15672779083252
# Surrogate acc on unlabled data: 0.069
# Attack loss: 10.27405071258545
# Surrogate loss on unlabled data: 10.366013526916504
# Surrogate acc on unlabled data: 0.07
# Attack loss: 10.439737319946289
# Surrogate loss on unlabled data: 10.818866729736328
# Surrogate acc on unlabled data: 0.07100000000000001
# Attack loss: 10.916192054748535
# Surrogate loss on unlabled data: 10.823775291442871
# Surrogate acc on unlabled data: 0.07200000000000001
# Attack loss: 10.93741226196289
# Surrogate loss on unlabled data: 10.274160385131836
# Surrogate acc on unlabled data: 0.07100000000000001
# Attack loss: 10.411226272583008
# Surrogate loss on unlabled data: 11.472900390625
# Surrogate acc on unlabled data: 0.07100000000000001
# Attack loss: 11.63199234008789
# Surrogate loss on unlabled data: 10.469358444213867
# Surrogate acc on unlabled data: 0.074
# Attack loss: 10.617507934570312
# Surrogate loss on unlabled data: 11.04634952545166
# Surrogate acc on unlabled data: 0.07
# Attack loss: 11.265673637390137
# Surrogate loss on unlabled data: 10.462163925170898
# Surrogate acc on unlabled data: 0.07
# Attack loss: 10.635786056518555
# Surrogate loss on unlabled data: 11.00456714630127
# Surrogate acc on unlabled data: 0.075
# Attack loss: 11.170145034790039
# Surrogate loss on unlabled data: 11.540102005004883
# Surrogate acc on unlabled data: 0.066
# Attack loss: 11.730222702026367
# Surrogate loss on unlabled data: 11.373299598693848
# Surrogate acc on unlabled data: 0.069
# Attack loss: 11.56044864654541
# Surrogate loss on unlabled data: 10.360020637512207
# Surrogate acc on unlabled data: 0.07200000000000001
# Attack loss: 10.573683738708496
# Surrogate loss on unlabled data: 10.894819259643555
# Surrogate acc on unlabled data: 0.066
# Attack loss: 11.065495491027832
# Surrogate loss on unlabled data: 10.192092895507812
# Surrogate acc on unlabled data: 0.07
# Attack loss: 10.398865699768066
# Surrogate loss on unlabled data: 11.616820335388184
# Surrogate acc on unlabled data: 0.07200000000000001
# Attack loss: 11.836183547973633
# Surrogate loss on unlabled data: 11.109539031982422
# Surrogate acc on unlabled data: 0.067
# Attack loss: 11.324366569519043
# Surrogate loss on unlabled data: 11.146997451782227
# Surrogate acc on unlabled data: 0.069
# Attack loss: 11.356938362121582
# Surrogate loss on unlabled data: 11.59225845336914
# Surrogate acc on unlabled data: 0.063
# Attack loss: 11.840063095092773
# Surrogate loss on unlabled data: 11.766911506652832
# Surrogate acc on unlabled data: 0.062
# Attack loss: 11.973669052124023
# Surrogate loss on unlabled data: 12.114649772644043
# Surrogate acc on unlabled data: 0.067
# Attack loss: 12.342276573181152
# Surrogate loss on unlabled data: 11.859583854675293
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 12.108280181884766
# Surrogate loss on unlabled data: 11.897334098815918
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 12.145201683044434
# Surrogate loss on unlabled data: 11.488251686096191
# Surrogate acc on unlabled data: 0.063
# Attack loss: 11.726079940795898
# Surrogate loss on unlabled data: 11.583906173706055
# Surrogate acc on unlabled data: 0.067
# Attack loss: 11.865345001220703
# Surrogate loss on unlabled data: 11.577958106994629
# Surrogate acc on unlabled data: 0.062
# Attack loss: 11.848785400390625
# Surrogate loss on unlabled data: 11.441823959350586
# Surrogate acc on unlabled data: 0.06
# Attack loss: 11.715194702148438
# Surrogate loss on unlabled data: 12.0697660446167
# Surrogate acc on unlabled data: 0.06
# Attack loss: 12.363936424255371
# Surrogate loss on unlabled data: 12.400432586669922
# Surrogate acc on unlabled data: 0.061
# Attack loss: 12.662074089050293
# Surrogate loss on unlabled data: 11.550541877746582
# Surrogate acc on unlabled data: 0.062
# Attack loss: 11.772918701171875
# Surrogate loss on unlabled data: 11.706432342529297
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 11.950873374938965
# Surrogate loss on unlabled data: 11.790925979614258
# Surrogate acc on unlabled data: 0.063
# Attack loss: 12.051688194274902
# Surrogate loss on unlabled data: 11.530742645263672
# Surrogate acc on unlabled data: 0.066
# Attack loss: 11.787840843200684
# Surrogate loss on unlabled data: 11.87370491027832
# Surrogate acc on unlabled data: 0.063
# Attack loss: 12.1626558303833
# Surrogate loss on unlabled data: 11.934585571289062
# Surrogate acc on unlabled data: 0.056
# Attack loss: 12.193153381347656
# Surrogate loss on unlabled data: 12.146665573120117
# Surrogate acc on unlabled data: 0.058
# Attack loss: 12.44240665435791
# Surrogate loss on unlabled data: 11.90489387512207
# Surrogate acc on unlabled data: 0.063
# Attack loss: 12.222468376159668
# Surrogate loss on unlabled data: 12.847502708435059
# Surrogate acc on unlabled data: 0.057
# Attack loss: 13.17185115814209
# Surrogate loss on unlabled data: 11.222105026245117
# Surrogate acc on unlabled data: 0.056
# Attack loss: 11.474952697753906
# Surrogate loss on unlabled data: 12.055992126464844
# Surrogate acc on unlabled data: 0.053
# Attack loss: 12.354249000549316
# Surrogate loss on unlabled data: 11.535091400146484
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 11.840415954589844
# Surrogate loss on unlabled data: 11.914645195007324
# Surrogate acc on unlabled data: 0.051000000000000004
# Attack loss: 12.247965812683105
# Surrogate loss on unlabled data: 12.252077102661133
# Surrogate acc on unlabled data: 0.056
# Attack loss: 12.578814506530762
# Surrogate loss on unlabled data: 11.745134353637695
# Surrogate acc on unlabled data: 0.055
# Attack loss: 12.044243812561035
# Surrogate loss on unlabled data: 12.39264965057373
# Surrogate acc on unlabled data: 0.053
# Attack loss: 12.715657234191895
# Surrogate loss on unlabled data: 12.212039947509766
# Surrogate acc on unlabled data: 0.055
# Attack loss: 12.551097869873047
# Surrogate loss on unlabled data: 12.51528263092041
# Surrogate acc on unlabled data: 0.054
# Attack loss: 12.886221885681152
# Surrogate loss on unlabled data: 11.986960411071777
# Surrogate acc on unlabled data: 0.051000000000000004
# Attack loss: 12.28791618347168
# Surrogate loss on unlabled data: 12.244000434875488
# Surrogate acc on unlabled data: 0.054
# Attack loss: 12.597797393798828
# Surrogate loss on unlabled data: 12.357793807983398
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 12.709257125854492
# Surrogate loss on unlabled data: 12.071956634521484
# Surrogate acc on unlabled data: 0.056
# Attack loss: 12.443559646606445
# Surrogate loss on unlabled data: 11.728360176086426
# Surrogate acc on unlabled data: 0.057
# Attack loss: 12.048770904541016
# Surrogate loss on unlabled data: 12.723295211791992
# Surrogate acc on unlabled data: 0.055
# Attack loss: 13.104859352111816
# Surrogate loss on unlabled data: 11.72907829284668
# Surrogate acc on unlabled data: 0.058
# Attack loss: 12.10666561126709
# Surrogate loss on unlabled data: 12.780871391296387
# Surrogate acc on unlabled data: 0.055
# Attack loss: 13.1742525100708
# Surrogate loss on unlabled data: 11.945395469665527
# Surrogate acc on unlabled data: 0.054
# Attack loss: 12.313118934631348
# Surrogate loss on unlabled data: 12.105867385864258
# Surrogate acc on unlabled data: 0.054
# Attack loss: 12.476300239562988
# Surrogate loss on unlabled data: 12.940163612365723
# Surrogate acc on unlabled data: 0.055
# Attack loss: 13.32829761505127
# Surrogate loss on unlabled data: 12.531913757324219
# Surrogate acc on unlabled data: 0.056
# Attack loss: 12.95457935333252
# Surrogate loss on unlabled data: 11.919720649719238
# Surrogate acc on unlabled data: 0.06
# Attack loss: 12.322697639465332
# Surrogate loss on unlabled data: 12.100522994995117
# Surrogate acc on unlabled data: 0.054
# Attack loss: 12.529337882995605
# Surrogate loss on unlabled data: 12.994006156921387
# Surrogate acc on unlabled data: 0.058
# Attack loss: 13.445303916931152
# Surrogate loss on unlabled data: 12.238577842712402
# Surrogate acc on unlabled data: 0.056
# Attack loss: 12.67248821258545
# Surrogate loss on unlabled data: 12.265538215637207
# Surrogate acc on unlabled data: 0.057
# Attack loss: 12.65480899810791
# Surrogate loss on unlabled data: 12.91513729095459
# Surrogate acc on unlabled data: 0.054
# Attack loss: 13.364376068115234
# Surrogate loss on unlabled data: 11.58289909362793
# Surrogate acc on unlabled data: 0.054
# Attack loss: 11.976554870605469
# Surrogate loss on unlabled data: 13.219558715820312
# Surrogate acc on unlabled data: 0.055
# Attack loss: 13.662075996398926
# Surrogate loss on unlabled data: 13.191779136657715
# Surrogate acc on unlabled data: 0.058
# Attack loss: 13.63606071472168
# Surrogate loss on unlabled data: 12.736004829406738
# Surrogate acc on unlabled data: 0.053
# Attack loss: 13.18820858001709
# Surrogate loss on unlabled data: 12.362929344177246
# Surrogate acc on unlabled data: 0.055
# Attack loss: 12.818574905395508
# Surrogate loss on unlabled data: 12.201313018798828
# Surrogate acc on unlabled data: 0.055
# Attack loss: 12.63144302368164
# Surrogate loss on unlabled data: 13.30406379699707
# Surrogate acc on unlabled data: 0.054
# Attack loss: 13.781516075134277
# Surrogate loss on unlabled data: 12.620162963867188
# Surrogate acc on unlabled data: 0.06
# Attack loss: 13.095587730407715
# Surrogate loss on unlabled data: 13.726560592651367
# Surrogate acc on unlabled data: 0.053
# Attack loss: 14.208815574645996
# Surrogate loss on unlabled data: 12.085355758666992
# Surrogate acc on unlabled data: 0.055
# Attack loss: 12.512995719909668
# Surrogate loss on unlabled data: 11.6478271484375
# Surrogate acc on unlabled data: 0.056
# Attack loss: 12.079011917114258
# Surrogate loss on unlabled data: 13.239082336425781
# Surrogate acc on unlabled data: 0.055
# Attack loss: 13.726591110229492
# Surrogate loss on unlabled data: 13.233437538146973
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 13.711068153381348
# Surrogate loss on unlabled data: 13.274796485900879
# Surrogate acc on unlabled data: 0.053
# Attack loss: 13.808943748474121
# Surrogate loss on unlabled data: 14.036308288574219
# Surrogate acc on unlabled data: 0.053
# Attack loss: 14.556941986083984
# Surrogate loss on unlabled data: 13.103296279907227
# Surrogate acc on unlabled data: 0.057
# Attack loss: 13.602807998657227
# Surrogate loss on unlabled data: 13.438706398010254
# Surrogate acc on unlabled data: 0.055
# Attack loss: 13.961092948913574
# Surrogate loss on unlabled data: 13.174447059631348
# Surrogate acc on unlabled data: 0.056
# Attack loss: 13.712679862976074
# Surrogate loss on unlabled data: 13.350895881652832
# Surrogate acc on unlabled data: 0.055
# Attack loss: 13.881918907165527
# Surrogate loss on unlabled data: 14.341920852661133
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 14.888679504394531
# Surrogate loss on unlabled data: 14.01636791229248
# Surrogate acc on unlabled data: 0.058
# Attack loss: 14.554716110229492
# Surrogate loss on unlabled data: 13.266355514526367
# Surrogate acc on unlabled data: 0.056
# Attack loss: 13.79896068572998
# Surrogate loss on unlabled data: 12.952826499938965
# Surrogate acc on unlabled data: 0.053
# Attack loss: 13.439269065856934
# Surrogate loss on unlabled data: 13.151567459106445
# Surrogate acc on unlabled data: 0.051000000000000004
# Attack loss: 13.659165382385254
# Surrogate loss on unlabled data: 14.348278999328613
# Surrogate acc on unlabled data: 0.049
# Attack loss: 14.91671085357666
# Surrogate loss on unlabled data: 14.13383674621582
# Surrogate acc on unlabled data: 0.054
# Attack loss: 14.689074516296387
# Surrogate loss on unlabled data: 13.488537788391113
# Surrogate acc on unlabled data: 0.056
# Attack loss: 14.023550033569336
# Surrogate loss on unlabled data: 14.105137825012207
# Surrogate acc on unlabled data: 0.054
# Attack loss: 14.697760581970215
# Surrogate loss on unlabled data: 14.191192626953125
# Surrogate acc on unlabled data: 0.054
# Attack loss: 14.749249458312988
# Surrogate loss on unlabled data: 13.852575302124023
# Surrogate acc on unlabled data: 0.053
# Attack loss: 14.409514427185059
# Surrogate loss on unlabled data: 13.612701416015625
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 14.112448692321777
# Surrogate loss on unlabled data: 12.900050163269043
# Surrogate acc on unlabled data: 0.057
# Attack loss: 13.427605628967285
# Surrogate loss on unlabled data: 14.008537292480469
# Surrogate acc on unlabled data: 0.056
# Attack loss: 14.568551063537598
# Surrogate loss on unlabled data: 14.229743003845215
# Surrogate acc on unlabled data: 0.056
# Attack loss: 14.807270050048828
# Surrogate loss on unlabled data: 13.989346504211426
# Surrogate acc on unlabled data: 0.057
# Attack loss: 14.551629066467285
# Surrogate loss on unlabled data: 14.245965957641602
# Surrogate acc on unlabled data: 0.06
# Attack loss: 14.817448616027832
# Surrogate loss on unlabled data: 14.596627235412598
# Surrogate acc on unlabled data: 0.055
# Attack loss: 15.167712211608887
# Surrogate loss on unlabled data: 14.012619972229004
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 14.604058265686035
# Surrogate loss on unlabled data: 13.77701473236084
# Surrogate acc on unlabled data: 0.055
# Attack loss: 14.331467628479004
# Surrogate loss on unlabled data: 13.421968460083008
# Surrogate acc on unlabled data: 0.055
# Attack loss: 13.976808547973633
# Surrogate loss on unlabled data: 13.591191291809082
# Surrogate acc on unlabled data: 0.054
# Attack loss: 14.183586120605469
# Surrogate loss on unlabled data: 14.510351181030273
# Surrogate acc on unlabled data: 0.06
# Attack loss: 15.12525463104248
# Surrogate loss on unlabled data: 13.688989639282227
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 14.288387298583984
# Surrogate loss on unlabled data: 13.783429145812988
# Surrogate acc on unlabled data: 0.057
# Attack loss: 14.344111442565918
# Surrogate loss on unlabled data: 14.960811614990234
# Surrogate acc on unlabled data: 0.058
# Attack loss: 15.581306457519531
# Surrogate loss on unlabled data: 14.652338981628418
# Surrogate acc on unlabled data: 0.058
# Attack loss: 15.280920028686523
# Surrogate loss on unlabled data: 14.813921928405762
# Surrogate acc on unlabled data: 0.053
# Attack loss: 15.43842887878418
# Surrogate loss on unlabled data: 15.485633850097656
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.14512825012207
# Surrogate loss on unlabled data: 14.04624080657959
# Surrogate acc on unlabled data: 0.054
# Attack loss: 14.632484436035156
# Surrogate loss on unlabled data: 14.755294799804688
# Surrogate acc on unlabled data: 0.056
# Attack loss: 15.39877986907959
# Surrogate loss on unlabled data: 14.864148139953613
# Surrogate acc on unlabled data: 0.057
# Attack loss: 15.517780303955078
# Surrogate loss on unlabled data: 14.282691955566406
# Surrogate acc on unlabled data: 0.054
# Attack loss: 14.930349349975586
# Surrogate loss on unlabled data: 14.218421936035156
# Surrogate acc on unlabled data: 0.053
# Attack loss: 14.849037170410156
# Surrogate loss on unlabled data: 14.584318161010742
# Surrogate acc on unlabled data: 0.057
# Attack loss: 15.208346366882324
# Surrogate loss on unlabled data: 14.866788864135742
# Surrogate acc on unlabled data: 0.053
# Attack loss: 15.541521072387695
# Surrogate loss on unlabled data: 13.989599227905273
# Surrogate acc on unlabled data: 0.056
# Attack loss: 14.623394012451172
# Surrogate loss on unlabled data: 14.878049850463867
# Surrogate acc on unlabled data: 0.054
# Attack loss: 15.55521011352539
# Surrogate loss on unlabled data: 15.460111618041992
# Surrogate acc on unlabled data: 0.058
# Attack loss: 16.155107498168945
# Surrogate loss on unlabled data: 15.523590087890625
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.224225997924805
# Surrogate loss on unlabled data: 13.994452476501465
# Surrogate acc on unlabled data: 0.05
# Attack loss: 14.614913940429688
# Surrogate loss on unlabled data: 14.142247200012207
# Surrogate acc on unlabled data: 0.056
# Attack loss: 14.772275924682617
# Surrogate loss on unlabled data: 15.41689395904541
# Surrogate acc on unlabled data: 0.058
# Attack loss: 16.116697311401367
# Surrogate loss on unlabled data: 15.06946086883545
# Surrogate acc on unlabled data: 0.053
# Attack loss: 15.757367134094238
# Surrogate loss on unlabled data: 15.95564079284668
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.67523193359375
# Surrogate loss on unlabled data: 14.541939735412598
# Surrogate acc on unlabled data: 0.053
# Attack loss: 15.208891868591309
# Surrogate loss on unlabled data: 15.380023002624512
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.098892211914062
# Surrogate loss on unlabled data: 14.714737892150879
# Surrogate acc on unlabled data: 0.054
# Attack loss: 15.39102554321289
# Surrogate loss on unlabled data: 14.624517440795898
# Surrogate acc on unlabled data: 0.055
# Attack loss: 15.327457427978516
# Surrogate loss on unlabled data: 14.302173614501953
# Surrogate acc on unlabled data: 0.053
# Attack loss: 14.96863079071045
# Surrogate loss on unlabled data: 14.54688549041748
# Surrogate acc on unlabled data: 0.055
# Attack loss: 15.23437786102295
# Surrogate loss on unlabled data: 13.835378646850586
# Surrogate acc on unlabled data: 0.057
# Attack loss: 14.495677947998047
# Surrogate loss on unlabled data: 15.138459205627441
# Surrogate acc on unlabled data: 0.055
# Attack loss: 15.857076644897461
# Surrogate loss on unlabled data: 15.003824234008789
# Surrogate acc on unlabled data: 0.051000000000000004
# Attack loss: 15.713988304138184
# Surrogate loss on unlabled data: 14.538411140441895
# Surrogate acc on unlabled data: 0.053
# Attack loss: 15.235669136047363
# Surrogate loss on unlabled data: 14.395097732543945
# Surrogate acc on unlabled data: 0.054
# Attack loss: 15.114167213439941
# Surrogate loss on unlabled data: 14.880829811096191
# Surrogate acc on unlabled data: 0.056
# Attack loss: 15.597606658935547
# Surrogate loss on unlabled data: 15.12240982055664
# Surrogate acc on unlabled data: 0.054
# Attack loss: 15.849831581115723
# Surrogate loss on unlabled data: 14.990825653076172
# Surrogate acc on unlabled data: 0.056
# Attack loss: 15.715513229370117
# Surrogate loss on unlabled data: 15.94472599029541
# Surrogate acc on unlabled data: 0.053
# Attack loss: 16.71755027770996
# Surrogate loss on unlabled data: 15.423394203186035
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.180313110351562
# Surrogate loss on unlabled data: 15.109895706176758
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 15.853883743286133
# Surrogate loss on unlabled data: 15.617595672607422
# Surrogate acc on unlabled data: 0.053
# Attack loss: 16.38433837890625
# Surrogate loss on unlabled data: 14.785459518432617
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 15.525714874267578
# Surrogate loss on unlabled data: 14.941202163696289
# Surrogate acc on unlabled data: 0.054
# Attack loss: 15.704354286193848
# Surrogate loss on unlabled data: 15.44935131072998
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.237539291381836
# Surrogate loss on unlabled data: 15.278968811035156
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 16.042734146118164
# Surrogate loss on unlabled data: 15.133145332336426
# Surrogate acc on unlabled data: 0.058
# Attack loss: 15.906271934509277
# Surrogate loss on unlabled data: 16.06139373779297
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.89873695373535
# Surrogate loss on unlabled data: 16.260578155517578
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 17.13327407836914
# Surrogate loss on unlabled data: 15.291231155395508
# Surrogate acc on unlabled data: 0.053
# Attack loss: 16.081722259521484
# Surrogate loss on unlabled data: 15.615891456604004
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.4509334564209
# Surrogate loss on unlabled data: 15.16384506225586
# Surrogate acc on unlabled data: 0.054
# Attack loss: 15.937396049499512
# Surrogate loss on unlabled data: 15.460638999938965
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.265565872192383
# Surrogate loss on unlabled data: 16.157726287841797
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 17.013460159301758
# Surrogate loss on unlabled data: 15.823945999145508
# Surrogate acc on unlabled data: 0.053
# Attack loss: 16.659255981445312
# Surrogate loss on unlabled data: 15.356122016906738
# Surrogate acc on unlabled data: 0.053
# Attack loss: 16.162864685058594
# Surrogate loss on unlabled data: 15.289125442504883
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.108726501464844
# Surrogate loss on unlabled data: 15.758465766906738
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.575952529907227
# Surrogate loss on unlabled data: 15.574164390563965
# Surrogate acc on unlabled data: 0.057
# Attack loss: 16.421842575073242
# Surrogate loss on unlabled data: 15.360882759094238
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.178565979003906
# Surrogate loss on unlabled data: 16.32467269897461
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.1817569732666
# Surrogate loss on unlabled data: 15.854395866394043
# Surrogate acc on unlabled data: 0.057
# Attack loss: 16.705963134765625
# Surrogate loss on unlabled data: 15.720952987670898
# Surrogate acc on unlabled data: 0.057
# Attack loss: 16.564453125
# Surrogate loss on unlabled data: 15.183286666870117
# Surrogate acc on unlabled data: 0.058
# Attack loss: 15.986486434936523
# Surrogate loss on unlabled data: 15.207937240600586
# Surrogate acc on unlabled data: 0.058
# Attack loss: 16.034320831298828
# Surrogate loss on unlabled data: 15.896880149841309
# Surrogate acc on unlabled data: 0.057
# Attack loss: 16.767642974853516
# Surrogate loss on unlabled data: 15.952156066894531
# Surrogate acc on unlabled data: 0.057
# Attack loss: 16.821311950683594
# Surrogate loss on unlabled data: 14.505142211914062
# Surrogate acc on unlabled data: 0.057
# Attack loss: 15.324204444885254
# Surrogate loss on unlabled data: 16.51620864868164
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.429096221923828
# Surrogate loss on unlabled data: 15.371350288391113
# Surrogate acc on unlabled data: 0.058
# Attack loss: 16.21929931640625
# Surrogate loss on unlabled data: 16.454626083374023
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.349056243896484
# Surrogate loss on unlabled data: 15.312023162841797
# Surrogate acc on unlabled data: 0.057
# Attack loss: 16.152986526489258
# Surrogate loss on unlabled data: 15.74940013885498
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.60967254638672
# Surrogate loss on unlabled data: 16.42520523071289
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.336088180541992
# Surrogate loss on unlabled data: 15.645149230957031
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.509225845336914
# Surrogate loss on unlabled data: 16.22459602355957
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.13694190979004
# Surrogate loss on unlabled data: 15.684534072875977
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.564678192138672
# Surrogate loss on unlabled data: 15.510711669921875
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.375131607055664
# Surrogate loss on unlabled data: 15.620018005371094
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.482725143432617
# Surrogate loss on unlabled data: 16.1989803314209
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.112821578979492
# Surrogate loss on unlabled data: 16.41715431213379
# Surrogate acc on unlabled data: 0.057
# Attack loss: 17.347074508666992
# Surrogate loss on unlabled data: 15.553979873657227
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.445528030395508
# Surrogate loss on unlabled data: 15.480302810668945
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.360631942749023
# Surrogate loss on unlabled data: 16.373411178588867
# Surrogate acc on unlabled data: 0.054
# Attack loss: 17.305313110351562
# Surrogate loss on unlabled data: 15.640426635742188
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 16.523088455200195
# Surrogate loss on unlabled data: 15.89294147491455
# Surrogate acc on unlabled data: 0.053
# Attack loss: 16.81619644165039
# Surrogate loss on unlabled data: 16.02574348449707
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.95994758605957
# Surrogate loss on unlabled data: 17.557798385620117
# Surrogate acc on unlabled data: 0.053
# Attack loss: 18.562564849853516
# Surrogate loss on unlabled data: 16.82380485534668
# Surrogate acc on unlabled data: 0.054
# Attack loss: 17.774526596069336
# Surrogate loss on unlabled data: 16.31810188293457
# Surrogate acc on unlabled data: 0.054
# Attack loss: 17.276912689208984
# Surrogate loss on unlabled data: 14.485091209411621
# Surrogate acc on unlabled data: 0.055
# Attack loss: 15.311985969543457
# Surrogate loss on unlabled data: 16.329545974731445
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 17.274547576904297
# Surrogate loss on unlabled data: 14.912117004394531
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 15.784311294555664
# Surrogate loss on unlabled data: 15.43007755279541
# Surrogate acc on unlabled data: 0.053
# Attack loss: 16.33905601501465
# Surrogate loss on unlabled data: 16.665897369384766
# Surrogate acc on unlabled data: 0.054
# Attack loss: 17.619564056396484
# Surrogate loss on unlabled data: 15.872306823730469
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.812463760375977
# Surrogate loss on unlabled data: 15.785351753234863
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 16.684429168701172
# Surrogate loss on unlabled data: 17.183744430541992
# Surrogate acc on unlabled data: 0.054
# Attack loss: 18.17592430114746
# Surrogate loss on unlabled data: 16.27845573425293
# Surrogate acc on unlabled data: 0.053
# Attack loss: 17.227252960205078
# Surrogate loss on unlabled data: 15.521519660949707
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.427061080932617
# Surrogate loss on unlabled data: 17.506593704223633
# Surrogate acc on unlabled data: 0.053
# Attack loss: 18.532241821289062
# Surrogate loss on unlabled data: 16.556304931640625
# Surrogate acc on unlabled data: 0.053
# Attack loss: 17.536344528198242
# Surrogate loss on unlabled data: 14.5317964553833
# Surrogate acc on unlabled data: 0.053
# Attack loss: 15.38284969329834
# Surrogate loss on unlabled data: 16.771203994750977
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.76422691345215
# Surrogate loss on unlabled data: 16.31861114501953
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.273807525634766
# Surrogate loss on unlabled data: 16.329614639282227
# Surrogate acc on unlabled data: 0.054
# Attack loss: 17.322086334228516
# Surrogate loss on unlabled data: 15.51332950592041
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.42156219482422
# Surrogate loss on unlabled data: 16.70585823059082
# Surrogate acc on unlabled data: 0.052000000000000005
# Attack loss: 17.693771362304688
# Surrogate loss on unlabled data: 15.138962745666504
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.02981948852539
# Surrogate loss on unlabled data: 16.423059463500977
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.41706657409668
# Surrogate loss on unlabled data: 16.04391098022461
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.994890213012695
# Surrogate loss on unlabled data: 16.986759185791016
# Surrogate acc on unlabled data: 0.055
# Attack loss: 18.016706466674805
# Surrogate loss on unlabled data: 16.152915954589844
# Surrogate acc on unlabled data: 0.054
# Attack loss: 17.13273811340332
# Surrogate loss on unlabled data: 16.28969383239746
# Surrogate acc on unlabled data: 0.054
# Attack loss: 17.27924156188965
# Surrogate loss on unlabled data: 15.522945404052734
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.479690551757812
# Surrogate loss on unlabled data: 16.659934997558594
# Surrogate acc on unlabled data: 0.057
# Attack loss: 17.70492172241211
# Surrogate loss on unlabled data: 15.516234397888184
# Surrogate acc on unlabled data: 0.058
# Attack loss: 16.468948364257812
# Surrogate loss on unlabled data: 16.157737731933594
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.155864715576172
# Surrogate loss on unlabled data: 17.558246612548828
# Surrogate acc on unlabled data: 0.055
# Attack loss: 18.642925262451172
# Surrogate loss on unlabled data: 16.854089736938477
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.87727165222168
# Surrogate loss on unlabled data: 17.788219451904297
# Surrogate acc on unlabled data: 0.058
# Attack loss: 18.89816665649414
# Surrogate loss on unlabled data: 16.86200714111328
# Surrogate acc on unlabled data: 0.058
# Attack loss: 17.91094970703125
# Surrogate loss on unlabled data: 16.9603214263916
# Surrogate acc on unlabled data: 0.058
# Attack loss: 18.025808334350586
# Surrogate loss on unlabled data: 16.76970100402832
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.803531646728516
# Surrogate loss on unlabled data: 16.22037696838379
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.205026626586914
# Surrogate loss on unlabled data: 17.288076400756836
# Surrogate acc on unlabled data: 0.055
# Attack loss: 18.340124130249023
# Surrogate loss on unlabled data: 15.951126098632812
# Surrogate acc on unlabled data: 0.055
# Attack loss: 16.931055068969727
# Surrogate loss on unlabled data: 14.49736213684082
# Surrogate acc on unlabled data: 0.054
# Attack loss: 15.42143440246582
# Surrogate loss on unlabled data: 16.933429718017578
# Surrogate acc on unlabled data: 0.057
# Attack loss: 17.992212295532227
# Surrogate loss on unlabled data: 16.346202850341797
# Surrogate acc on unlabled data: 0.057
# Attack loss: 17.364910125732422
# Surrogate loss on unlabled data: 14.916329383850098
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 15.888114929199219
# Surrogate loss on unlabled data: 16.365402221679688
# Surrogate acc on unlabled data: 0.058
# Attack loss: 17.374237060546875
# Surrogate loss on unlabled data: 16.708023071289062
# Surrogate acc on unlabled data: 0.058
# Attack loss: 17.762252807617188
# Surrogate loss on unlabled data: 17.433929443359375
# Surrogate acc on unlabled data: 0.055
# Attack loss: 18.534107208251953
# Surrogate loss on unlabled data: 17.448843002319336
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 18.563491821289062
# Surrogate loss on unlabled data: 16.639326095581055
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.691781997680664
# Surrogate loss on unlabled data: 16.78792953491211
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.835634231567383
# Surrogate loss on unlabled data: 16.34645652770996
# Surrogate acc on unlabled data: 0.057
# Attack loss: 17.39769172668457
# Surrogate loss on unlabled data: 17.472469329833984
# Surrogate acc on unlabled data: 0.058
# Attack loss: 18.593839645385742
# Surrogate loss on unlabled data: 16.590770721435547
# Surrogate acc on unlabled data: 0.057
# Attack loss: 17.662342071533203
# Surrogate loss on unlabled data: 16.146854400634766
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.202770233154297
# Surrogate loss on unlabled data: 17.12810516357422
# Surrogate acc on unlabled data: 0.059000000000000004
# Attack loss: 18.23253059387207
# Surrogate loss on unlabled data: 15.874482154846191
# Surrogate acc on unlabled data: 0.056
# Attack loss: 16.919343948364258
# Surrogate loss on unlabled data: 17.96912956237793
# Surrogate acc on unlabled data: 0.057
# Attack loss: 19.127538681030273
# Surrogate loss on unlabled data: 17.62277603149414
# Surrogate acc on unlabled data: 0.056
# Attack loss: 18.767841339111328
# Surrogate loss on unlabled data: 16.273794174194336
# Surrogate acc on unlabled data: 0.058
# Attack loss: 17.334699630737305
# Surrogate loss on unlabled data: 17.5344295501709
# Surrogate acc on unlabled data: 0.057
# Attack loss: 18.662593841552734
# Surrogate loss on unlabled data: 17.536605834960938
# Surrogate acc on unlabled data: 0.057
# Attack loss: 18.661792755126953
# Surrogate loss on unlabled data: 17.221599578857422
# Surrogate acc on unlabled data: 0.057
# Attack loss: 18.337936401367188
# Surrogate loss on unlabled data: 16.137802124023438
# Surrogate acc on unlabled data: 0.055
# Attack loss: 17.18621253967285
# Surrogate loss on unlabled data: 15.893383026123047
# Surrogate acc on unlabled data: 0.054
# Attack loss: 16.920074462890625
# Surrogate loss on unlabled data: 17.016908645629883
# Surrogate acc on unlabled data: 0.055
# Attack loss: 18.129558563232422
# Surrogate loss on unlabled data: 17.452924728393555
# Surrogate acc on unlabled data: 0.058
# Attack loss: 18.603233337402344
# Surrogate loss on unlabled data: 17.745710372924805
# Surrogate acc on unlabled data: 0.058
# Attack loss: 18.902212142944336
# Surrogate loss on unlabled data: 16.299116134643555
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.3480167388916
# Surrogate loss on unlabled data: 17.702735900878906
# Surrogate acc on unlabled data: 0.056
# Attack loss: 18.85955047607422
# Surrogate loss on unlabled data: 17.401103973388672
# Surrogate acc on unlabled data: 0.058
# Attack loss: 18.552589416503906
# Surrogate loss on unlabled data: 14.590437889099121
# Surrogate acc on unlabled data: 0.058
# Attack loss: 15.552328109741211
# Surrogate loss on unlabled data: 17.972570419311523
# Surrogate acc on unlabled data: 0.057
# Attack loss: 19.14589500427246
# Surrogate loss on unlabled data: 17.20642852783203
# Surrogate acc on unlabled data: 0.057
# Attack loss: 18.335100173950195
# Surrogate loss on unlabled data: 16.18722915649414
# Surrogate acc on unlabled data: 0.056
# Attack loss: 17.26443862915039
# Surrogate loss on unlabled data: 17.97622299194336
# Surrogate acc on unlabled data: 0.062
# Attack loss: 19.160017013549805
# ...
#  (tensor(62, device='cuda:0'), tensor(2992, device='cuda:0')),
#  (tensor(17, device='cuda:0'), tensor(1982, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(2992, device='cuda:0')),
#  (tensor(62, device='cuda:0'), tensor(1819, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(1192, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2457, device='cuda:0')),
#  (tensor(2, device='cuda:0'), tensor(1558, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(2261, device='cuda:0')),
#  (tensor(62, device='cuda:0'), tensor(1856, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(2813, device='cuda:0')),
#  (tensor(43, device='cuda:0'), tensor(196, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(2521, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(1171, device='cuda:0')),
#  (tensor(67, device='cuda:0'), tensor(415, device='cuda:0')),
#  (tensor(2, device='cuda:0'), tensor(415, device='cuda:0')),
#  (tensor(28, device='cuda:0'), tensor(3144, device='cuda:0')),
#  (tensor(42, device='cuda:0'), tensor(1139, device='cuda:0')),
#  (tensor(36, device='cuda:0'), tensor(1139, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(2903, device='cuda:0')),
#  (tensor(34, device='cuda:0'), tensor(955, device='cuda:0')),
#  (tensor(87, device='cuda:0'), tensor(255, device='cuda:0')),
#  (tensor(86, device='cuda:0'), tensor(3082, device='cuda:0')),
#  (tensor(83, device='cuda:0'), tensor(665, device='cuda:0')),
#  (tensor(92, device='cuda:0'), tensor(1320, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2157, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(42, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(1895, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(2917, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(3208, device='cuda:0')),
#  (tensor(8, device='cuda:0'), tensor(1459, device='cuda:0')),
#  (tensor(98, device='cuda:0'), tensor(2464, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(3211, device='cuda:0')),
#  (tensor(47, device='cuda:0'), tensor(3211, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(1254, device='cuda:0')),
#  (tensor(87, device='cuda:0'), tensor(1892, device='cuda:0')),
#  (tensor(46, device='cuda:0'), tensor(1095, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(3322, device='cuda:0')),
#  (tensor(62, device='cuda:0'), tensor(845, device='cuda:0')),
#  (tensor(31, device='cuda:0'), tensor(2535, device='cuda:0')),
#  (tensor(65, device='cuda:0'), tensor(1164, device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(134, device='cuda:0')),
#  (tensor(8, device='cuda:0'), tensor(354, device='cuda:0')),
#  (tensor(15, device='cuda:0'), tensor(2337, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(2150, device='cuda:0')),
#  (tensor(107, device='cuda:0'), tensor(2777, device='cuda:0')),
#  (tensor(55, device='cuda:0'), tensor(2602, device='cuda:0')),
#  (tensor(99, device='cuda:0'), tensor(1161, device='cuda:0')),
#  (tensor(118, device='cuda:0'), tensor(1933, device='cuda:0')),
#  (tensor(95, device='cuda:0'), tensor(1544, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(3190, device='cuda:0')),
#  (tensor(94, device='cuda:0'), tensor(489, device='cuda:0')),
#  (tensor(67, device='cuda:0'), tensor(817, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(442, device='cuda:0')),
#  (tensor(78, device='cuda:0'), tensor(3142, device='cuda:0')),
#  (tensor(8, device='cuda:0'), tensor(1338, device='cuda:0')),
#  (tensor(83, device='cuda:0'), tensor(195, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(2105, device='cuda:0')),
#  (tensor(56, device='cuda:0'), tensor(2105, device='cuda:0')),
#  (tensor(118, device='cuda:0'), tensor(173, device='cuda:0')),
#  (tensor(24, device='cuda:0'), tensor(660, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(1303, device='cuda:0')),
#  (tensor(6, device='cuda:0'), tensor(3146, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(2280, device='cuda:0')),
#  (tensor(65, device='cuda:0'), tensor(1490, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(2951, device='cuda:0')),
#  (tensor(49, device='cuda:0'), tensor(678, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(173, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(3179, device='cuda:0')),
#  (tensor(84, device='cuda:0'), tensor(3311, device='cuda:0')),
#  (tensor(63, device='cuda:0'), tensor(674, device='cuda:0')),
#  (tensor(86, device='cuda:0'), tensor(458, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(1939, device='cuda:0')),
#  (tensor(117, device='cuda:0'), tensor(1252, device='cuda:0')),
#  (tensor(84, device='cuda:0'), tensor(3208, device='cuda:0')),
#  (tensor(10, device='cuda:0'), tensor(2878, device='cuda:0')),
#  (tensor(44, device='cuda:0'), tensor(2253, device='cuda:0')),
#  (tensor(15, device='cuda:0'), tensor(845, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(3323, device='cuda:0')),
#  (tensor(117, device='cuda:0'), tensor(1526, device='cuda:0')),
#  (tensor(67, device='cuda:0'), tensor(3261, device='cuda:0')),
#  (tensor(83, device='cuda:0'), tensor(1420, device='cuda:0')),
#  (tensor(42, device='cuda:0'), tensor(2030, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(1844, device='cuda:0')),
#  (tensor(67, device='cuda:0'), tensor(88, device='cuda:0')),
#  (tensor(88, device='cuda:0'), tensor(260, device='cuda:0')),
#  (tensor(86, device='cuda:0'), tensor(1199, device='cuda:0')),
#  (tensor(70, device='cuda:0'), tensor(1289, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(576, device='cuda:0')),
#  (tensor(105, device='cuda:0'), tensor(1488, device='cuda:0')),
#  (tensor(89, device='cuda:0'), tensor(564, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(1844, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(812, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(2563, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(2159, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(594, device='cuda:0')),
#  (tensor(4, device='cuda:0'), tensor(3133, device='cuda:0')),
#  (tensor(84, device='cuda:0'), tensor
device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(283, device='cuda:0')),
#  (tensor(90, device='cuda:0'), tensor(1882, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(961, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(3161, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(148, device='cuda:0')),
#  (tensor(87, device='cuda:0'), tensor(391, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(3279, device='cuda:0')),
#  (tensor(38, device='cuda:0'), tensor(1274, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(1475, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(1280, device='cuda:0')),
#  (tensor(77, device='cuda:0'), tensor(1150, device='cuda:0')),
#  (tensor(56, device='cuda:0'), tensor(184, device='cuda:0')),
#  (tensor(97, device='cuda:0'), tensor(2341, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2137, device='cuda:0')),
#  (tensor(118, device='cuda:0'), tensor(3279, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(1690, device='cuda:0')),
#  (tensor(118, device='cuda:0'), tensor(2529, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2777, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(1280, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(939, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(3297, device='cuda:0')),
#  (tensor(107, device='cuda:0'), tensor(1498, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2530, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(2342, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2724, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2658, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(802, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2951, device='cuda:0')),
#  (tensor(95, device='cuda:0'), tensor(3114, device='cuda:0')),
#  (tensor(31, device='cuda:0'), tensor(1376, device='cuda:0')),
#  (tensor(19, device='cuda:0'), tensor(50, device='cuda:0')),
#  (tensor(2, device='cuda:0'), tensor(1147, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(1458, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(1778, device='cuda:0')),
#  (tensor(48, device='cuda:0'), tensor(1882, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(2659, device='cuda:0')),
#  (tensor(1132, device='cuda:0'), tensor(2103, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(1249, device='cuda:0')),
#  (tensor(109, device='cuda:0'), tensor(1783, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(3092, device='cuda:0')),
#  (tensor(92, device='cuda:0'), tensor(2895, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(2881, device='cuda:0')),
#  (tensor(109, device='cuda:0'), tensor(2057, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(3092, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(1449, device='cuda:0')),
#  (tensor(80, device='cuda:0'), tensor(370, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(3168, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2606, device='cuda:0')),
#  (tensor(87, device='cuda:0'), tensor(2141, device='cuda:0')),
#  (tensor(109, device='cuda:0'), tensor(363, device='cuda:0')),
#  (tensor(110, device='cuda:0'), tensor(3258, device='cuda:0')),
#  (tensor(17, device='cuda:0'), tensor(1833, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(1150, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(343, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(343, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(2074, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(1246, device='cuda:0')),
#  (tensor(105, device='cuda:0'), tensor(1354, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(2223, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(3112, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(774, device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(973, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(1790, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(3151, device='cuda:0')),
#  (tensor(56, device='cuda:0'), tensor(1338, device='cuda:0')),
#  (tensor(7, device='cuda:0'), tensor(44, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(761, device='cuda:0')),
#  (tensor(1578, device='cuda:0'), tensor(2294, device='cuda:0')),
#  ...]

# %%
# list_save_path = "../attacks/citeseer_gcn_edges_full_run.pth"
# torch.save(edges_to_add, list_save_path)

# %%
new_edges = [(x.item(), y.item()) for (x, y) in sorted_keys]

# %%
list_save_path = "../attacks/citeseer_gcn_edges_full_run.pth"
torch.save(new_edges, list_save_path)

# %%
len(new_edges)
# Out:
# 9104

# %%
new_edges
# Out:
# [(53, 2359),
#  (113, 2873),
#  (107, 845),
#  (42, 3260),
#  (119, 892),
#  (118, 3122),
#  (113, 3058),
#  (110, 1549),
#  (48, 2333),
#  (31, 1602),
#  (42, 1500),
#  (30, 1375),
#  (25, 3170),
#  (53, 3173),
#  (113, 3319),
#  (115, 2593),
#  (113, 939),
#  (53, 3190),
#  (30, 2881),
#  (64, 91),
#  (21, 48),
#  (48, 93),
#  (48, 2231),
#  (48, 3005),
#  (113, 1552),
#  (48, 3285),
#  (48, 3065),
#  (48, 3123),
#  (31, 223),
#  (10, 2908),
#  (74, 2563),
#  (38, 105),
#  (107, 838),
#  (48, 3219),
#  (34, 3004),
#  (89, 2600),
#  (85, 3082),
#  (112, 2946),
#  (42, 2508),
#  (96, 1285),
#  (99, 1497),
#  (116, 2796),
#  (5, 2566),
#  (113, 3123),
#  (48, 3201),
#  (119, 2724),
#  (8, 3040),
#  (113, 503),
#  (48, 1959),
#  (3, 26),
#  (48, 1632),
#  (118, 3297),
#  (113, 437),
#  (90, 2997),
#  (42, 2294),
#  (82, 745),
#  (35, 3318),
#  (18, 1274),
#  (104, 2769),
#  (100, 1515),
#  (53, 1738),
#  (2175, 3318),
#  (32, 1674),
#  (74, 2725),
#  (2, 426),
#  (89, 1199),
#  (47, 1166),
#  (56, 2008),
#  (60, 2019),
#  (42, 359),
#  (592, 1538),
#  (117, 3170),
#  (41, 1118),
#  (35, 1870),
#  (80, 2171),
#  (71, 1969),
#  (95, 134),
#  (25, 1361),
#  (117, 2611),
#  (105, 3317),
#  (74, 2929),
#  (74, 2011),
#  (25, 1823),
#  (51, 871),
#  (29, 3145),
#  (25, 1454),
#  (21, 67),
#  (52, 1631),
#  (59, 1579),
#  (70, 2123),
#  (63, 419),
#  (35, 1474),
#  (67, 1315),
#  (17, 146),
#  (86, 903),
#  (116, 1924),
#  (73, 3121),
#  (25, 892),
#  (0, 2265),
#  (9, 1819),
#  (88, 2050),
#  (24, 209),
#  (35, 2099),
#  (61, 782),
#  (55, 1735),
#  (5, 1805),
#  (39, 1892),
#  (62, 1146),
#  (25, 3258),
#  (77, 2636),
#  (111, 2528),
#  (11, 432),
#  (35, 3202),
#  (12, 1179),
#  (83, 390),
#  (86, 420),
#  (32, 233),
#  (3, 196),
#  (94, 947),
#  (79, 1897),
#  (14, 2410),
#  (67, 728),
#  (80, 2099),
#  (67, 3251),
#  (67, 952),
#  (15, 391),
#  (47, 145),
#  (2, 2273),
#  (67, 3121),
#  (90, 2332),
#  (52, 283),
#  (90, 1882),
#  (35, 961),
#  (25, 3161),
#  (112, 148),
#  (87, 391),
#  (50, 3279),
#  (38, 1274),
#  (50, 1475),
#  (112, 1280),
#  (77, 1150),
#  (56, 184),
#  (97, 2341),
#  (50, 2137),
#  (118, 3279),
#  (35, 1690),
#  (118, 2529),
#  (50, 2777),
#  (50, 1280),
#  (50, 939),
#  (50, 3297),
#  (107, 1498),
#  (50, 2530),
#  (66, 2342),
#  (50, 2724),
#  (50, 2658),
#  (112, 802),
#  (50, 2951),
#  (95, 3114),
#  (31, 1376),
#  (19, 50),
#  (2, 1147),
#  (50, 1458),
#  (112, 1778),
#  (48, 1882),
#  (25, 2659),
#  (1132, 2103),
#  (50, 1249),
#  (109, 1783),
#  (112, 3092),
#  (92, 2895),
#  (112, 2881),
#  (109, 2057),
#  (50, 3092),
#  (112, 1449),
#  (80, 370),
#  (112, 3168),
#  (50, 2606),
#  (87, 2141),
#  (109, 363),
#  (110, 3258),
#  (17, 1833),
#  (68, 1150),
#  (112, 343),
#  (25, 343),
#  (50, 2074),
#  (50, 1246),
#  (105, 1354),
#  (119, 2223),
#  (25, 3112),
#  (112, 774),
#  (52, 973),
#  (35, 1790),
#  (25, 3151),
#  (56, 1338),
#  (7, 44),
#  (25, 761),
#  (1578, 2294),
#  ...]

# %%
# # save model
# model_save_path = "multi_metattack_gcn_model.pth"
# torch.save(model.state_dict(), model_save_path)

# # save edges
# list_save_path = "multi_metattack_edges_list.pth"
# torch.save(edges_to_add, list_save_path)

# %%
# loaded_model_state_dict = torch.load(model_save_path)

# model = GCN(data.x.shape[1], cora_dataset.num_classes, [16]).to(device)
# model.load_state_dict(loaded_model_state_dict)

# # Load the saved list
# edges_to_add = torch.load(list_save_path)

# %%
# model_save_path = "multi_metattack_gcn_model.pth"
# list_save_path = "multi_metattack_edges_list.pth"

# %%
# model, edges_to_add, train = load_model_and_edges(model_save_path, list_save_path, data.x.shape[1], cora_dataset.num_classes, [16], device)

# %%
# G, initial_edge_count, ptb_rate, budget = initialize(data, _ptb_rate=0.15)

# %%
# len(edges_to_add)

# %%
# def two_phase_attack(split):
#     diff_threshold = abs(initial_loss/200)
#     first_phase_edges = int(budget * split)
#     second_phase_percent = ptb_rate * (1 - split) * 1/2
#     print(second_phase_percent)
#     accuracies = []
#     G = to_networkx(data, to_undirected=True)
    
#     data_copy = copy.copy(data)
#     i, j = 0, 0 # i - number added, j - spot in list
#     while i < first_phase_edges:
#         u, v = edges_to_add[j]
    
#         G.add_edge(u, v)
    
#         modified_data = from_networkx(G).to(device)
#         modified_data.x = data.x 
#         modified_data.y = data.y 
#         modified_data.train_mask = data.train_mask
#         modified_data.test_mask = data.test_mask
    
#         modified_loss, modified_accuracy = train.test(modified_data)
#         # print(modified_loss)
    
#         if (abs(modified_loss - initial_loss) / max(modified_loss, initial_loss)) <= diff_threshold:
#         # if modified_accuracy == initial_accuracy:
#             # print(modified_accuracy, i)
#             i += 1
#             # accuracies.append(modified_accuracy)
#             accuracies.append(modified_loss)
#         else:
#             # print(i, 'miss!')
#             G.remove_edge(u, v)
            
#         j += 1
    
#     modified_data = from_networkx(G).to(device)
#     modified_data.x = data.x 
#     modified_data.y = data.y 
#     modified_data.train_mask = data.train_mask
#     modified_data.test_mask = data.test_mask
    
#     attacker = Metattack(modified_data, device=device)
#     attacker.setup_surrogate(model,
#                              labeled_nodes=data.train_mask,
#                              unlabeled_nodes=data.test_mask, lambda_=0.)
#     attacker.reset()
#     attacker.attack(second_phase_percent)

#     degs = defaultdict(tuple)
    
#     for k, v in attacker._added_edges.items():
#         degs[v] = (k, True)
        
#     for k, v in attacker._removed_edges.items():
#         degs[v] = (k, False)
    
#     for _, second in degs.items():
#         u, v = second[0]
#         if second[1]:
#             G.add_edge(u, v)
#         else:
#             G.remove_edge(u, v)
    
#         modified_data = from_networkx(G).to(device)
#         modified_data.x = data.x 
#         modified_data.y = data.y 
#         modified_data.train_mask = data.train_mask
#         modified_data.test_mask = data.test_mask
    
#         modified_loss, modified_accuracy = train.test(modified_data)
    
#         # accuracies.append(modified_accuracy)
#         accuracies.append(modified_loss)

#     print(accuracies)
#     return accuracies

# %%
# # asplits = [0, 0.5, 0.7, 0.9]
# split_dic_acc = defaultdict(list)
# # split_dic_loss = defaaultdict(list)
# itrs = defaultdict(int)

# %%
# for s in splits:
#     print(s)
#     split_dic_acc[s], split_dic_loss[s], itrs[s] = two_phase_attack_greedy(data, train, model, s, edges_to_add, constant_fn, device, verbose=True)

# %%
# plot_results(split_dic_acc, ptb_rate, "Greedy", "no", "constant", "accuracy")

# %%
# plot_results(split_dic_loss, ptb_rate, "Greedy", "no", "constant", "loss")

# %%
# itrs
